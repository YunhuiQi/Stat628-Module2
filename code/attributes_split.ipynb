# %% [markdown]
# # The file is to select and integrate gym data.
# ## Instruction: The file generates two csv files - 'bs_train_attr.csv' and 'review_train.csv'. 'bs_train_attr.csv' is business_train data of gym with the attributes split from column 'attributes'. 'review_train.csv' is review_train data of gym.

# %%
#Import modules
import json
import re
import pandas as pd
import nltk
import math
from math import sqrt
import sklearn
import statsmodels.api as sm
from nltk.stem import WordNetLemmatizer 
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np
from nltk.tokenize import word_tokenize
import string
from nltk.corpus import stopwords
from tqdm import tqdm
from sklearn import linear_model
import collections
from gensim.models import Word2Vec
from gensim.models import word2vec
import multiprocessing
import time
import re
import csv
import numpy as np

# %% [markdown]
# ### First, we read the 'business_train.json', and save it as 'bs_train'.Then we select the gym data, save it as 'business_train', and transform it as data frame.

# %%
#Read business_train.json file
bs_train = []
with open('../data/business_train.json',"r") as f:
        try:
            while True:
                line = f.readline()
                if line:
                    bs_tra = json.loads(line)
                    bs_train.append(bs_tra)
                    #print(bs_train)
                else:
                    break
        except:
            f.close()
bs_train = pd.DataFrame(bs_train)         #set bs_train data as data frame

# %%
#Select the gym data from the whole data set.
category = bs_train[["categories"]]           #Store the categories of bs_train in 'category'
pat_rest = re.compile(r'.*Gym.*')             #Match where there is 'Gym'
num_no_rest = []
for row in tqdm(range(len(category))):                  #Checking by row, if the 'categories' is not defined  
    if category.iloc[row]['categories'] is None:        #save it in row.   
        num_no_rest.append(row)
    else:
        if not pat_rest.match(category.iloc[row]['categories']):       #Checking by row, if the 'categories' is
            num_no_rest.append(row)                                    #not in category, save it in row.     
bs_train = bs_train.drop(index = num_no_rest)               #Drop the rows which are not clssified as 'Gym'.
# Out:
# 100%|██████████| 154606/154606 [00:26<00:00, 5746.55it/s]

# %%
bs_train
# Out:
#                                                attributes  business_id  \
# 16      {'AcceptsInsurance': 'True', 'ByAppointmentOnl...       104170
# 397                {'BusinessAcceptsCreditCards': 'True'}        49708
# 441     {'GoodForKids': 'True', 'ByAppointmentOnly': '...       173815
# 494     {'GoodForKids': 'False', 'ByAppointmentOnly': ...       183154
# 568     {'BusinessParking': '{'garage': False, 'street...       138163
# 622     {'GoodForKids': 'False', 'BusinessParking': '{...        17594
# 681     {'BikeParking': 'False', 'ByAppointmentOnly': ...       106407
# 710     {'BusinessAcceptsCreditCards': 'True', 'GoodFo...       170000
# 713     {'BusinessAcceptsCreditCards': 'True', 'ByAppo...        69171
# 801     {'BusinessAcceptsCreditCards': 'True', 'ByAppo...        22591
# 844     {'BusinessParking': '{'garage': False, 'street...       112422
# 1013    {'BusinessParking': '{'garage': False, 'street...       118824
# 1071    {'ByAppointmentOnly': 'False', 'WheelchairAcce...       133243
# 1173    {'GoodForKids': 'True', 'BikeParking': 'True',...       170891
# 1262    {'GoodForKids': 'False', 'BusinessParking': 'N...         2701
# 1298    {'BusinessAcceptsCreditCards': 'True', 'Busine...       160597
# 1527    {'GoodForKids': 'True', 'BusinessParking': '{'...        86652
# 1551    {'ByAppointmentOnly': 'False', 'BusinessParkin...       123027
# 1739    {'GoodForKids': 'True', 'BusinessParking': '{'...       100610
# 1775    {'BusinessAcceptsCreditCards': 'True', 'Busine...       117728
# 1806                             {'GoodForKids': 'False'}       171580
# 2000                              {'GoodForKids': 'True'}       159183
# 2017    {'GoodForKids': 'False', 'BusinessParking': '{...       183266
# 2227    {'ByAppointmentOnly': 'False', 'BusinessAccept...        99656
# 2234                     {'WheelchairAccessible': 'True'}       182036
# 2312    {'GoodForKids': 'True', 'BikeParking': 'True',...       142505
# 2419    {'GoodForKids': 'False', 'BusinessParking': '{...        49256
# 2488    {'BusinessAcceptsCreditCards': 'True', 'ByAppo...        13626
# 2506    {'ByAppointmentOnly': 'False', 'BusinessParkin...        27502
# 2561    {'BusinessAcceptsCreditCards': 'True', 'GoodFo...       147475
# ...                                                   ...          ...
# 151948  {'BusinessParking': '{'garage': False, 'street...       151091
# 152089                                               None        89519
# 152307  {'BikeParking': 'True', 'GoodForKids': 'False'...         2199
# 152376                                               None       148039
# 152416  {'ByAppointmentOnly': 'False', 'BusinessAccept...       161200
# 152428  {'GoodForKids': 'True', 'BikeParking': 'True',...       120614
# 152548  {'BusinessParking': '{'garage': False, 'street...        15559
# 152554                            {'GoodForKids': 'True'}        39633
# 152560                                               None         4071
# 152627  {'GoodForKids': 'True', 'BusinessAcceptsCredit...       187716
# 152829  {'GoodForKids': 'False', 'BusinessParking': '{...        85703
# 152849  {'BusinessAcceptsBitcoin': 'False', 'BusinessA...       118799
# 152899                            {'GoodForKids': 'True'}        69840
# 152907  {'GoodForKids': 'True', 'ByAppointmentOnly': '...       114802
# 152983                           {'GoodForKids': 'False'}       179226
# 153041  {'GoodForKids': 'True', 'BikeParking': 'True',...        28766
# 153067  {'BusinessParking': '{'garage': False, 'street...       144722
# 153128  {'WheelchairAccessible': 'True', 'GoodForKids'...        56730
# 153287  {'ByAppointmentOnly': 'False', 'BusinessParkin...       185399
# 153356  {'BikeParking': 'True', 'ByAppointmentOnly': '...        17674
# 153399                            {'GoodForKids': 'True'}        33519
# 153481  {'ByAppointmentOnly': 'False', 'GoodForKids': ...        50356
# 153572  {'GoodForKids': 'False', 'BikeParking': 'True'...        42305
# 153705  {'BikeParking': 'True', 'ByAppointmentOnly': '...        45758
# 153935  {'GoodForKids': 'False', 'BusinessParking': '{...        87927
# 154030  {'GoodForKids': 'True', 'ByAppointmentOnly': '...       141316
# 154076  {'BusinessParking': '{'garage': False, 'street...        53225
# 154203  {'BusinessParking': '{'garage': False, 'street...       180262
# 154347  {'GoodForKids': 'False', 'BikeParking': 'False...        40423
# 154478  {'BusinessParking': '{'garage': False, 'street...       166479
#
#                                                categories             city  \
# 16      Trainers, Health & Medical, Active Life, Physi...          Toronto
# 397     Active Life, Trainers, Fitness & Instruction, ...  North Las Vegas
# 441              Gyms, Fitness & Instruction, Active Life         Glendale
# 494              Fitness & Instruction, Gyms, Active Life          Toronto
# 568     Gyms, Active Life, Fitness & Instruction, Card...           Verdun
# 622     Active Life, Cardio Classes, Fitness & Instruc...        Las Vegas
# 681     Taekwondo, Gyms, Martial Arts, Education, Acti...        Henderson
# 710     Sports Clubs, Local Services, Community Servic...        Charlotte
# 713     Active Life, Gyms, Trainers, Fitness & Instruc...        Charlotte
# 801     Gyms, Trainers, Active Life, Fitness & Instruc...        Henderson
# 844     Professional Sports Teams, Fitness & Instructi...          Toronto
# 1013    Nutritionists, Sports Clubs, Fitness & Instruc...         Chandler
# 1071    Trampoline Parks, Active Life, Fitness & Instr...          Calgary
# 1173    Trainers, Water Parks, Fitness & Instruction, ...      Sun Prairie
# 1262    Gyms, Trainers, Active Life, Fitness & Instruc...           Mentor
# 1298    Active Life, Martial Arts, Fitness & Instructi...            Tempe
# 1527    Gyms, Fitness & Instruction, Trainers, Physica...        Las Vegas
# 1551    Beauty & Spas, Active Life, Day Spas, Fitness ...          Toronto
# 1739    Trainers, Active Life, Fitness & Instruction, ...         Surprise
# 1775    Party & Event Planning, Gymnastics, Active Lif...        Charlotte
# 1806    Fitness & Instruction, Active Life, Gyms, Boxi...          Phoenix
# 2000    Muay Thai, Fitness & Instruction, Active Life,...          Toronto
# 2017             Gyms, Active Life, Fitness & Instruction          Toronto
# 2227    Fitness & Instruction, Local Services, Active ...        Charlotte
# 2234                              Gymnastics, Active Life        Charlotte
# 2312    Gymnastics, Fitness & Instruction, Active Life...         Chandler
# 2419    Trainers, Yoga, Gyms, Sports Clubs, Fitness & ...          Toronto
# 2488    Active Life, Fitness & Instruction, Gyms, Trai...       Scottsdale
# 2506    Active Life, Gyms, Fitness & Instruction, Trai...         Glendale
# 2561    Interval Training Gyms, Trainers, Active Life,...        El Mirage
# ...                                                   ...              ...
# 151948  Trainers, Sports Clubs, Active Life, Yoga, Gym...            Tempe
# 152089  Nutritionists, Fitness & Instruction, Gyms, He...          Phoenix
# 152307  Gyms, Sports Clubs, Active Life, Trainers, Fit...          Vaughan
# 152376  Fitness & Instruction, Active Life, Trainers, ...          Gilbert
# 152416  Fitness & Instruction, Gyms, Amusement Parks, ...      Bridgeville
# 152428                            Gymnastics, Active Life         Chandler
# 152548  Trainers, Yoga, Nutritionists, Fitness & Instr...          Toronto
# 152554           Active Life, Fitness & Instruction, Gyms  North Las Vegas
# 152560  Gyms, Weight Loss Centers, Active Life, Traine...        Las Vegas
# 152627  Gyms, Active Life, Fitness & Instruction, Inte...         Chandler
# 152829  Active Life, Gyms, Fitness & Instruction, Weig...         Chandler
# 152849  Active Life, Shopping, Gyms, Fitness/Exercise ...          Phoenix
# 152899  Gyms, Active Life, Boot Camps, Fitness & Instr...            Tempe
# 152907  Fitness & Instruction, Gyms, Trainers, Active ...        Las Vegas
# 152983  Active Life, Trainers, Gyms, Fitness & Instruc...          Toronto
# 153041  Gymnastics, Active Life, Fitness & Instruction...       Scottsdale
# 153067  Health & Medical, Fitness & Instruction, Yoga,...             Mesa
# 153128  Trainers, Nutritionists, Fitness & Instruction...        Henderson
# 153287           Gyms, Fitness & Instruction, Active Life      Mississauga
# 153356  Dance Studios, Fitness & Instruction, Active L...          Toronto
# 153399  Trainers, Fitness & Instruction, Pilates, Gyms...        Rock Hill
# 153481  Yoga, Sports Clubs, Fitness & Instruction, Gym...          Phoenix
# 153572  Gyms, Trainers, Fitness & Instruction, Active ...   Sagamore Hills
# 153705           Active Life, Gyms, Fitness & Instruction      Mississauga
# 153935  Gyms, Trainers, Fitness & Instruction, Active ...          Madison
# 154030  Active Life, Fitness & Instruction, Sports Clu...         Montréal
# 154076  Active Life, Climbing, Yoga, Gyms, Rock Climbi...        Henderson
# 154203  Sports Clubs, Trainers, Gyms, Fitness & Instru...          Calgary
# 154347   Active Life, Gyms, Boxing, Fitness & Instruction          Toronto
# 154478  Active Life, Child Care & Day Care, Local Serv...        Las Vegas
#
#                                                     hours  is_open   latitude  \
# 16      {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...        1  43.645041
# 397     {'Monday': '15:30-19:30', 'Tuesday': '15:30-19...        1  36.276098
# 441     {'Monday': '17:30-21:0', 'Tuesday': '17:30-21:...        1  33.520077
# 494     {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...        1  43.638122
# 568                                                  None        1  45.465383
# 622     {'Monday': '4:30-21:30', 'Tuesday': '4:30-20:3...        1  36.298839
# 681     {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...        1  36.042930
# 710     {'Monday': '5:0-21:30', 'Tuesday': '5:0-21:30'...        1  35.315808
# 713     {'Monday': '6:0-21:0', 'Tuesday': '6:0-21:0', ...        1  35.101964
# 801     {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.035840
# 844     {'Monday': '9:30-20:30', 'Tuesday': '6:30-20:3...        1  43.697910
# 1013    {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.305601
# 1071    {'Monday': '10:0-23:0', 'Tuesday': '10:0-23:0'...        1  51.134775
# 1173    {'Monday': '6:0-21:0', 'Tuesday': '4:30-23:30'...        1  43.194386
# 1262    {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  41.655991
# 1298    {'Monday': '8:0-20:0', 'Tuesday': '8:0-20:0', ...        1  33.335594
# 1527    {'Monday': '6:30-19:30', 'Tuesday': '6:30-19:3...        1  36.123094
# 1551    {'Monday': '5:0-22:0', 'Tuesday': '5:0-22:0', ...        1  43.648133
# 1739    {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.637169
# 1775    {'Monday': '13:0-20:0', 'Tuesday': '9:0-20:0',...        1  35.040559
# 1806                                                 None        0  33.510207
# 2000    {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1  43.647117
# 2017    {'Monday': '6:15-20:15', 'Tuesday': '6:15-20:1...        1  43.698444
# 2227    {'Monday': '5:30-21:0', 'Tuesday': '5:30-21:0'...        1  35.246555
# 2234    {'Monday': '14:0-19:30', 'Tuesday': '10:0-19:3...        1  35.152534
# 2312    {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...        1  33.280531
# 2419    {'Monday': '5:0-23:0', 'Tuesday': '5:0-23:0', ...        1  43.730316
# 2488    {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  33.635440
# 2506    {'Monday': '5:0-0:0', 'Tuesday': '5:0-0:0', 'W...        1  33.597368
# 2561    {'Monday': '15:30-20:30', 'Tuesday': '15:30-20...        1  33.560950
# ...                                                   ...      ...        ...
# 151948  {'Monday': '5:0-23:0', 'Tuesday': '5:0-23:0', ...        0  33.377219
# 152089  {'Monday': '5:30-20:0', 'Tuesday': '5:30-20:0'...        1  33.677071
# 152307                                               None        1  43.847475
# 152376  {'Monday': '16:0-19:30', 'Tuesday': '5:0-19:30...        1  33.378512
# 152416  {'Monday': '15:0-21:0', 'Tuesday': '15:0-20:0'...        1  40.366080
# 152428  {'Monday': '9:0-19:0', 'Tuesday': '9:0-19:0', ...        1  33.334375
# 152548  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  43.703935
# 152554                                               None        0  36.276040
# 152560  {'Monday': '15:0-19:0', 'Tuesday': '15:0-19:0'...        1  36.190835
# 152627                                               None        1  33.307985
# 152829  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        0  33.219445
# 152849  {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...        1  33.478295
# 152899                                               None        0  33.423292
# 152907  {'Monday': '16:0-19:30', 'Tuesday': '16:0-18:3...        1  36.069831
# 152983                                               None        0  43.648850
# 153041  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:0', '...        1  33.638434
# 153067  {'Monday': '4:30-23:0', 'Tuesday': '4:30-23:0'...        1  33.438750
# 153128  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.012043
# 153287                                               None        1  43.523528
# 153356  {'Monday': '15:0-21:0', 'Tuesday': '15:0-21:0'...        1  43.672691
# 153399  {'Monday': '5:0-23:0', 'Tuesday': '5:0-23:0', ...        0  34.974497
# 153481  {'Monday': '5:0-23:0', 'Tuesday': '5:0-23:0', ...        1  33.511221
# 153572  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  41.315127
# 153705  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        0  43.582929
# 153935  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  43.072258
# 154030  {'Monday': '6:0-23:0', 'Tuesday': '6:0-23:0', ...        1  45.510899
# 154076  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...        1  36.051631
# 154203                                               None        1  50.986076
# 154347  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  43.672458
# 154478  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...        1  36.142744
#
#          longitude                                               name  \
# 16      -79.395799                                 Totum Life Science
# 397    -115.203534                                Iron Talon Crossfit
# 441    -112.184332                               Relentless Power Gym
# 494     -79.418156                       F45 Training Liberty Village
# 568     -73.566886                                     Energie Cardio
# 622    -115.279247       Orange Theory Fitness Las Vegas - Centennial
# 681    -115.116226                                      WTM Taekwondo
# 710     -80.778680                        University City Branch YMCA
# 713     -80.991144                                   Fitness Together
# 801    -115.098688                 24 Hour Fitness - Wigwam Henderson
# 844     -79.395536                                        Centre Ring
# 1013   -111.926051                                      Elite Fitness
# 1071   -114.035633                                    Flying Squirrel
# 1173    -89.224265                              Prairie Athletic Club
# 1262    -81.361762                            Planet Fitness - Mentor
# 1298   -111.907285                          BODY & BRAIN Yoga Tai Chi
# 1527   -115.298066                               CrossFit Social City
# 1551    -79.379509                                 Equinox Bay Street
# 1739   -112.395627                          Planet Fitness - Surprise
# 1775    -80.861280                        The Little Gym - Ballantyne
# 1806   -112.027204                                   Amenzone Fitness
# 2000    -79.404899  Toronto Kickboxing & Muay Thai Academy - Downtown
# 2017    -79.396814                                          Ferris360
# 2227    -80.808105                      Johnston Memorial Branch YMCA
# 2234    -80.744995                                  Zenith Gymnastics
# 2312   -111.799381                                   Arizona Dynamics
# 2419    -79.285628                                         LA Fitness
# 2488   -111.923830                                    Anytime Fitness
# 2506   -112.152908                                Youfit Health Clubs
# 2561   -112.343256                                CrossFit Unwavering
# ...            ...                                                ...
# 151948 -111.895443                                         LA Fitness
# 152089 -112.101757                       Turner Fit Personal Training
# 152307  -79.551909                                   GoodLife Fitness
# 152376 -111.749690                   North Gilbert Fit Body Boot Camp
# 152416  -80.107086                             Flight Trampoline Park
# 152428 -111.834408                              Gold Medal Gymnastics
# 152548  -79.412974                                     eMbody Fitness
# 152554 -115.179136                                         Gold's Gym
# 152560 -115.307418                                             Curves
# 152627 -111.946430                                      CrossFit Crew
# 152829 -111.824660                                       Snap Fitness
# 152849 -112.121672                        Christian's Fitness Factory
# 152899 -111.906571                                    CrossFit Haboob
# 152907 -115.298692                                         Jazzercise
# 152983  -79.391966                                    Extreme Fitness
# 153041 -111.883356                            Rebound Gymnastics West
# 153067 -111.734916                               Mountainside Fitness
# 153128 -114.964617                                      Big Scary Gym
# 153287  -79.707296                                          World Gym
# 153356  -79.319424                                 Cornerstone Studio
# 153399  -81.023194                       Omni Health & Fitness Center
# 153481 -112.083448                                         LA Fitness
# 153572  -81.553656                                    Anytime Fitness
# 153705  -79.717457                                             Gymify
# 153935  -89.398621                                    Anytime Fitness
# 154030  -73.621846                              Midtown Athletic Club
# 154076 -115.024090                        Origin Climbing and Fitness
# 154203 -114.042144                                   GoodLife Fitness
# 154347  -79.415988                                 Bloor Fitness 24/7
# 154478 -115.268720           EōS Fitness - Las Vegas: Sahara/Cimarron
#
#        postal_code state
# 16         M5V 1K4    ON
# 397          89084    NV
# 441          85301    AZ
# 494        M6K 3E7    ON
# 568        H4G 1V1    QC
# 622          89117    NV
# 681          89074    NV
# 710          28262    NC
# 713          28278    NC
# 801          89074    NV
# 844        M4S 1C1    ON
# 1013         85226    AZ
# 1071       T2E 6K2    AB
# 1173         53590    WI
# 1262         44060    OH
# 1298         85284    AZ
# 1527         89147    NV
# 1551       M5L 1E2    ON
# 1739         85374    AZ
# 1775         28277    NC
# 1806         85016    AZ
# 2000       M6J 1E3    ON
# 2017       M4S 1Z5    ON
# 2227         28205    NC
# 2234         28212    NC
# 2312         85286    AZ
# 2419       M1L 2M6    ON
# 2488         85254    AZ
# 2506         85304    AZ
# 2561         85335    AZ
# ...            ...   ...
# 151948       85283    AZ
# 152089       85027    AZ
# 152307     L4H 4J6    ON
# 152376       85234    AZ
# 152416       15017    PA
# 152428       85225    AZ
# 152548     M5N 1A5    ON
# 152554       89084    NV
# 152560       89134    NV
# 152627       85226    AZ
# 152829       85249    AZ
# 152849       85009    AZ
# 152899       85281    AZ
# 152907       89148    NV
# 152983     M5V 3M6    ON
# 153041       85260    AZ
# 153067       85205    AZ
# 153128       89015    NV
# 153287     L5L 0A2    ON
# 153356     M4L 2A5    ON
# 153399       29732    SC
# 153481       85013    AZ
# 153572       44067    OH
# 153705     L5M 1K8    ON
# 153935       53715    WI
# 154030     H3S 2V9    QC
# 154076       89011    NV
# 154203     T2H 3C1    AB
# 154347     M6G 1Y6    ON
# 154478       89117    NV
#
# [1886 rows x 11 columns]

# %% [markdown]
# ### Picking up the column 'attributes' of 'bs_train', we split it and take split attributes as separate columns. The corresponding data is Boolean value, saved as 'attr'.

# %%
#Have a look at the columns name of bs_train data.
bs_train.columns
# Out:
# Index(['attributes', 'business_id', 'categories', 'city', 'hours', 'is_open',
#        'latitude', 'longitude', 'name', 'postal_code', 'state'],
#       dtype='object')

# %%
#Split attributes by row, and save as new columns. 
bs_attr = list(dict(bs_train['attributes']).values())
attr = pd.DataFrame(bs_attr[0], index = [0])
for i in range(1,len(bs_attr)):
    attr = pd.concat([attr,pd.DataFrame(bs_attr[i],index = [i])])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %% [markdown]
# ### Then, we find that the split attribute - 'BusinessParking' is also dictionary-structured and has not so many missing values. We split it as new columns with the values as boolen, saved as 'parking'.

# %%
#Pick up the BusinessParking column. Split it and take the results as new columns.
bs_parking = list(dict(attr['BusinessParking']).values())
parking = pd.DataFrame(np.nan, index = [0,1], columns = ['garage','street','validated','lot', 'valet'])
for i in range(2,len(bs_parking)):               #Check by row, if there is no value available, add a new row of 'nan'     
    if pd.isnull(bs_parking[i]) == True:
        parking.loc[i] = np.nan
    else:
        parking = pd.concat([parking,pd.DataFrame(eval(bs_parking[i]), index = [i])])   #If the value is available, split it 
        parking[i:(i+1)] = (parking[i:(i+1)] == 1.0)                                    # and add as new row.
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %% [markdown]
# ### Next, we add the attributes from 'attr' and 'parking' to 'business_train'. We finally get the data with split attributes as seperate columns, saved as 'bs_train_attr'. Write it as 'bs_train_attr.csv'.

# %%
#Add the attributes as columns of business_train and save the new generated as business_train.
bs_train = bs_train.reset_index(drop=True)
bs_train_attr = pd.concat([bs_train,attr,parking],axis=1)
#Delet the dictionary-structured variables, which have been split as new columns.
bs_train_attr = bs_train_attr.drop(['BusinessParking','attributes'],axis=1) 
bs_train_attr.to_csv("bs_train_attr.csv",index = False)

# %% [markdown]
# ### Last, we read review_train.json, and save it as 'rv_train'. Then we select the gum data from rv_train according to business id from 'bs_train'.

# %%
#Read review_train.json file
rv_train = []
with open('../data/review_train.json',"r") as f:
        try:
            while True:
                line = f.readline()
                if line:
                    rv_tra = json.loads(line)
                    rv_train.append(rv_tra)          
                else:
                    break
        except:
            f.close()
rv_train = pd.DataFrame(rv_train)          #set rv_train data as data frame.

# %%
#According to 'business_id' column of business_train, we selec the gym data from rv_train.
#and save it as review_train.
id_gym = []
id_review = rv_train['business_id']
id_business = list(bs_train['business_id'])       
for i in range(len(rv_train)):                    
    if id_review[i] in id_business:                 #Checking by row, judge if it is in the list of business_id.
        id_gym.append(i)                            #If so, store the index in id_gym.
review_train = rv_train.loc[id_gym]
review_train.to_csv("review_train.csv",index=False)
